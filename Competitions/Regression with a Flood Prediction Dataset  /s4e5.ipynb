# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
df_test = pd.read_csv("playground-series-s4e5/test.csv")
df_train = pd.read_csv("playground-series-s4e5/train.csv")

# %%
#df_train.dtypes
df_train.head(5)
# Out:
#    id  MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# 0   0                 5                   8                5              8
# 1   1                 6                   7                4              4
# 2   2                 6                   5                6              7
# 3   3                 3                   4                6              5
# 4   4                 5                   3                2              6
#
#    Urbanization  ClimateChange  DamsQuality  Siltation  AgriculturalPractices  \
# 0             6              4            4          3                      3
# 1             8              8            3          5                      4
# 2             3              7            1          5                      4
# 3             4              8            4          7                      6
# 4             4              4            3          3                      3
#
#    ...  DrainageSystems  CoastalVulnerability  Landslides  Watersheds  \
# 0  ...                5                     3           3           5
# 1  ...                7                     2           0           3
# 2  ...                7                     3           7           5
# 3  ...                2                     4           7           4
# 4  ...                2                     2           6           6
#
#    DeterioratingInfrastructure  PopulationScore  WetlandLoss  \
# 0                            4                7            5
# 1                            5                3            3
# 2                            6                8            2
# 3                            4                6            5
# 4                            4                1            2
#
#    InadequatePlanning  PoliticalFactors  FloodProbability
# 0                   7                 3             0.445
# 1                   4                 3             0.450
# 2                   3                 3             0.530
# 3                   7                 5             0.535
# 4                   3                 5             0.415
#
# [5 rows x 22 columns]

# %%
df_train_features = df_train.drop(["id","FloodProbability"], axis=1)
df_train_label = df_train["FloodProbability"]
df_train_features
# Out:
#          MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# 0                       5                   8                5              8
# 1                       6                   7                4              4
# 2                       6                   5                6              7
# 3                       3                   4                6              5
# 4                       5                   3                2              6
# ...                   ...                 ...              ...            ...
# 1117952                 3                   3                4             10
# 1117953                 2                   2                4              3
# 1117954                 7                   3                9              4
# 1117955                 7                   3                3              7
# 1117956                 4                   5                6              9
#
#          Urbanization  ClimateChange  DamsQuality  Siltation  \
# 0                   6              4            4          3
# 1                   8              8            3          5
# 2                   3              7            1          5
# 3                   4              8            4          7
# 4                   4              4            3          3
# ...               ...            ...          ...        ...
# 1117952             4              5            5          7
# 1117953             9              5            8          1
# 1117954             6              5            9          1
# 1117955             5              2            3          4
# 1117956             5              5            2          8
#
#          AgriculturalPractices  Encroachments  \
# 0                            3              4
# 1                            4              6
# 2                            4              5
# 3                            6              8
# 4                            3              3
# ...                        ...            ...
# 1117952                     10              4
# 1117953                      3              5
# 1117954                      3              4
# 1117955                      6              4
# 1117956                      4              5
#
#          IneffectiveDisasterPreparedness  DrainageSystems  \
# 0                                      2                5
# 1                                      9                7
# 2                                      6                7
# 3                                      5                2
# 4                                      5                2
# ...                                  ...              ...
# 1117952                                3                7
# 1117953                                5                9
# 1117954                                5                5
# 1117955                                6                6
# 1117956                                1                4
#
#          CoastalVulnerability  Landslides  Watersheds  \
# 0                           3           3           5
# 1                           2           0           3
# 2                           3           7           5
# 3                           4           7           4
# 4                           2           6           6
# ...                       ...         ...         ...
# 1117952                     8           7           2
# 1117953                     4           4           3
# 1117954                     5           5           5
# 1117955                     8           5           3
# 1117956                     8           6           5
#
#          DeterioratingInfrastructure  PopulationScore  WetlandLoss  \
# 0                                  4                7            5
# 1                                  5                3            3
# 2                                  6                8            2
# 3                                  4                6            5
# 4                                  4                1            2
# ...                              ...              ...          ...
# 1117952                            2                1            4
# 1117953                            7                4            9
# 1117954                            6                5            5
# 1117955                            4                6            7
# 1117956                            5                6            7
#
#          InadequatePlanning  PoliticalFactors
# 0                         7                 3
# 1                         4                 3
# 2                         3                 3
# 3                         7                 5
# 4                         3                 5
# ...                     ...               ...
# 1117952                   6                 4
# 1117953                   4                 5
# 1117954                   2                 4
# 1117955                   6                 4
# 1117956                   7                 8
#
# [1117957 rows x 20 columns]

# %%
#Determine std dev of columns
df_train_features.std()
# Out:
# MonsoonIntensity                   2.056387
# TopographyDrainage                 2.093879
# RiverManagement                    2.072186
# Deforestation                      2.051689
# Urbanization                       2.083391
# ClimateChange                      2.057742
# DamsQuality                        2.083063
# Siltation                          2.065992
# AgriculturalPractices              2.068545
# Encroachments                      2.083324
# IneffectiveDisasterPreparedness    2.078141
# DrainageSystems                    2.072333
# CoastalVulnerability               2.088899
# Landslides                         2.078287
# Watersheds                         2.082395
# DeterioratingInfrastructure        2.064813
# PopulationScore                    2.074176
# WetlandLoss                        2.068696
# InadequatePlanning                 2.081123
# PoliticalFactors                   2.090350
# dtype: float64

# %%
x ,x_val , y, y_val = train_test_split(df_train_features,df_train_label, test_size=0.3, train_size=0.70, random_state=42, shuffle=True)

# %%
def predictAnl(model,x,y,x_val, y_val):
    model.fit(x,y)
    y_pred = model.predict(x_val)
    score = r2_score(y_val, y_pred)
    print(score)
    print(model.score(x,y))

# %%
lr_model = LinearRegression()

predictAnl(lr_model,x,y,x_val, y_val)
# Out:
# 0.845070099597821
# 0.8448973977650922
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 13
#      11 predictAnl(lr_model,x,y,x_val, y_val)
#      12 #predictAnl(Log_r,x,y,x_val, y_val)
# ---> 13 predictAnl(Log_rCV,x,y,x_val, y_val)
#
# Cell In[29], line 2, in predictAnl(model, x, y, x_val, y_val)
#       1 def predictAnl(model,x,y,x_val, y_val):
# ----> 2     model.fit(x,y)
#       3     y_pred = model.predict(x_val)
#       4     score = r2_score(y_val, y_pred)
#
# File /opt/homebrew/lib/python3.12/site-packages/sklearn/base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File /opt/homebrew/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1811, in LogisticRegressionCV.fit(self, X, y, sample_weight, **params)
#    1801     l1_ratios_ = [None]
#    1803 X, y = self._validate_data(
#    1804     X,
#    1805     y,
#    (...)
#    1809     accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1810 )
# -> 1811 check_classification_targets(y)
#    1813 class_weight = self.class_weight
#    1815 # Encode for string labels
#
# File /opt/homebrew/lib/python3.12/site-packages/sklearn/utils/multiclass.py:221, in check_classification_targets(y)
#     213 y_type = type_of_target(y, input_name="y")
#     214 if y_type not in [
#     215     "binary",
#     216     "multiclass",
#    (...)
#     219     "multilabel-sequences",
#     220 ]:
# --> 221     raise ValueError(
#     222         f"Unknown label type: {y_type}. Maybe you are trying to fit a "
#     223         "classifier, which expects discrete classes on a "
#     224         "regression target with continuous values."
#     225     )
#
# ValueError: Unknown label type: continuous. Maybe you are trying to fit a classifier, which expects discrete classes on a regression target with continuous values.

# %%
df_test_features = df_test.drop("id", axis = 1)
predictions = lr_model.predict(df_test_features)

# %%
df_submission= pd.DataFrame({
    'id':df_test["id"],
    "FloodProbability": predictions
})
df_submission.to_csv("submission.csv",index=False)
