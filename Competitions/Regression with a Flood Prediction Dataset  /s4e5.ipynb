# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df_test = pd.read_csv("playground-series-s4e5/test.csv")
df_train = pd.read_csv("playground-series-s4e5/train.csv")

# %%
#df_train.dtypes
df_train.head(5)
# Out:
#    id  MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# 0   0                 5                   8                5              8
# 1   1                 6                   7                4              4
# 2   2                 6                   5                6              7
# 3   3                 3                   4                6              5
# 4   4                 5                   3                2              6
#
#    Urbanization  ClimateChange  DamsQuality  Siltation  AgriculturalPractices  \
# 0             6              4            4          3                      3
# 1             8              8            3          5                      4
# 2             3              7            1          5                      4
# 3             4              8            4          7                      6
# 4             4              4            3          3                      3
#
# ...

# %%
df_train_features = df_train.drop("FloodProbability", axis=1)
df_train_label = df_train["FloodProbability"]
df_train_label
# Out:
# 0          0.445
# 1          0.450
# 2          0.530
# 3          0.535
# 4          0.415
#            ...
# 1117952    0.495
# 1117953    0.480
# 1117954    0.485
# 1117955    0.495
# 1117956    0.560
# Name: FloodProbability, Length: 1117957, dtype: float64

# %%
x ,y , x_val, y_val = train_test_split(df_train_features,df_train_label, test_size=0.3, train_size=0.70, random_state=42, shuffle=True)

# %%
regression_model = LinearRegression()
# Out:
#             id  MonsoonIntensity  TopographyDrainage  RiverManagement  \
# 276033  276033                 4                   3                2
# 884872  884872                 7                   9                2
# 544464  544464                 2                   3                4
# 396548  396548                 7                   3                5
# 977274  977274                 6                   5                6
# ...        ...               ...                 ...              ...
# 110268  110268                 4                   7                5
# 259178  259178                 3                   4                6
# 131932  131932                 5                   4                1
# 671155  671155                 6                  10                4
# 121958  121958                 5                   7                2
#
#         Deforestation  Urbanization  ClimateChange  DamsQuality  Siltation  \
# ...
