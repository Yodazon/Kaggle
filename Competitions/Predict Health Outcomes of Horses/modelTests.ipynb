# %%
import pandas as pd
import zipfile
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

from sklearn.metrics import mean_squared_error
from sklearn.metrics import f1_score

# %%
zf = zipfile.ZipFile("data\playground-series-s3e22.zip")
train_df = pd.read_csv(zf.open("train.csv"))
test_df = pd.read_csv(zf.open("test.csv"))

# %%
train_df.head(5).transpose()
# Out:
#                                    0              1              2  \
# id                                 0              1              2
# surgery                          yes            yes            yes
# age                            adult          adult          adult
# hospital_number               530001         533836         529812
# rectal_temp                     38.1           37.5           38.3
# pulse                          132.0           88.0          120.0
# respiratory_rate                24.0           12.0           28.0
# temp_of_extremities             cool           cool           cool
# peripheral_pulse             reduced         normal        reduced
# mucous_membrane        dark_cyanotic  pale_cyanotic      pale_pink
# capillary_refill_time     more_3_sec     more_3_sec     less_3_sec
# pain                       depressed      mild_pain   extreme_pain
# peristalsis                   absent         absent     hypomotile
# ...

# %%
dummy_train_df = pd.get_dummies(train_df, dtype = float)

# %%
#Features to be used in training model
x_feat = train_df.drop(["id" , "outcome"], axis = 1)

#label for training
y_label = train_df["outcome"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x_feat,y_label,test_size = 0.1, random_state = 25)

rf_model = RandomForestRegressor(random_state = 25)
rf_model.fit(x_train, y_train)
y_pred = rf_model.predict(x_test)

print(f1_score(y_test,y_pred))
print(mean_squared_error(y_test, y_pred,squared=False))
print(rf_model.score(x_train,y_train))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15324\3005123999.py in ?()
#       1 x_train, x_test, y_train, y_test = train_test_split(x_feat,y_label,test_size = 0.1, random_state = 25)
#       2
#       3 rf_model = RandomForestRegressor(random_state = 25)
# ----> 4 rf_model.fit(x_train, y_train)
#       5 y_pred = rf_model.predict(x_test)
#       6
#       7 print(f1_score(y_test,y_pred))
#
# c:\Users\heroa\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1147                 skip_parameter_validation=(
#    1148                     prefer_skip_nested_validation or global_skip_validation
#    1149                 )
#    1150             ):
# -> 1151                 return fit_method(estimator, *args, **kwargs)
#
# ...
